# %% [markdown]
# # MultiModal Document RAG with ColQwen2 and Llama 3.2 90B Vision
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/togethercomputer/together-cookbook/blob/main/MultiModal_RAG_with_Nvidia_Investor_Slide_Deck.ipynb)

# %% [markdown]
# ## Hardware Requirements
# *To ensure the notebook runs faster please change the runtime type to T4 GPU:
# `Runtime` -> `Change runtime type` -> `T4 GPU`*
#
# *You can also run this notebook on a 16Gb M1 Macbook Pro

# %% [markdown]
# ## Introduction
#
# In this notebook we will see how to use Multimodal RAG to chat with Nvidia's invester slide deck from last year. The [slide deck](https://s201.q4cdn.com/141608511/files/doc_presentations/2023/Oct/01/ndr_presentation_oct_2023_final.pdf) is 39 pages with a combination of text, visuals, tables, charts and annotations. The document structure and templates vary from page to page and is quite difficult to RAG over using traditional methods.
#
# We will be using a new multimodal approach!
#
# <img src="https://github.com/togethercomputer/together-cookbook/blob/main/images/Nvidia_collage.png?raw=1" width="500">

# %% [markdown]
# ## MultiModal RAG Workflow
#
# [ColPali](https://arxiv.org/abs/2407.01449) is a new multimodal retrieval system that seamlessly enables image retrieval.
#
# By directly encoding image patches, it eliminates the need for optical character recognition (OCR), or image captioning to extract text from PDFs.
#
# We will use `byaldi`, a library from [AnswerAI](https://www.answer.ai/), that makes it easier to work with an upgraded version of ColPali, called ColQwen2, to embed and retrieve images of our PDF documents.
#
# Retrieved pages will then be passed into the Llama-3.2 90B Vision model served via a [Together AI](https://www.together.ai/) inference endpoint for it to answer questions.
#
# To get a better explanation of how ColPali and the new Llama 3.2 Vision models work checkout the [blog post](https://www.together.ai/blog/multimodal-document-rag-with-llama-3-2-vision-and-colqwen2) connected to this notebook.

# %% [markdown]
# <img src="https://github.com/togethercomputer/together-cookbook/blob/main/images/mmrag_only.png?raw=1" width="600">

# %% [markdown]
# ### Install relevant libraries

# %%
# !pip install byaldi together pdf2image
# Out:
# Collecting byaldi
#   Downloading Byaldi-0.0.7-py3-none-any.whl.metadata (20 kB)
# Collecting together
#   Downloading together-1.5.4-py3-none-any.whl.metadata (14 kB)
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting colpali-engine<0.4.0,>=0.3.4 (from byaldi)
#   Downloading colpali_engine-0.3.8-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from byaldi) (0.4.1)
# Collecting mteb==1.6.35 (from byaldi)
#   Downloading mteb-1.6.35-py3-none-any.whl.metadata (23 kB)
# Collecting ninja (from byaldi)
#   Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: srsly in /usr/local/lib/python3.11/dist-packages (from byaldi) (2.5.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from byaldi) (2.6.0+cu124)
# Requirement already satisfied: transformers>=4.42.0 in /usr/local/lib/python3.11/dist-packages (from byaldi) (4.50.2)
# Collecting datasets>=2.2.0 (from mteb==1.6.35->byaldi)
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Collecting jsonlines (from mteb==1.6.35->byaldi)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mteb==1.6.35->byaldi) (2.0.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from mteb==1.6.35->byaldi) (2.32.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from mteb==1.6.35->byaldi) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mteb==1.6.35->byaldi) (1.14.1)
# Requirement already satisfied: sentence-transformers>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from mteb==1.6.35->byaldi) (3.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from mteb==1.6.35->byaldi) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from mteb==1.6.35->byaldi) (13.9.4)
# Collecting pytrec-eval-terrier>=0.5.6 (from mteb==1.6.35->byaldi)
#   Downloading pytrec_eval_terrier-0.5.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (777 bytes)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from mteb==1.6.35->byaldi) (2.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from mteb==1.6.35->byaldi) (4.13.0)
# Collecting eval-type-backport (from mteb==1.6.35->byaldi)
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.3 in /usr/local/lib/python3.11/dist-packages (from together) (3.11.14)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from together) (8.1.8)
# Requirement already satisfied: filelock<4.0.0,>=3.13.1 in /usr/local/lib/python3.11/dist-packages (from together) (3.18.0)
# Requirement already satisfied: pillow<12.0.0,>=11.1.0 in /usr/local/lib/python3.11/dist-packages (from together) (11.1.0)
# Requirement already satisfied: pyarrow>=10.0.1 in /usr/local/lib/python3.11/dist-packages (from together) (18.1.0)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from together) (0.9.0)
# Requirement already satisfied: typer<0.16,>=0.9 in /usr/local/lib/python3.11/dist-packages (from together) (0.15.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.18.3)
# Collecting gputil (from colpali-engine<0.4.0,>=0.3.4->byaldi)
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: peft<0.15.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from colpali-engine<0.4.0,>=0.3.4->byaldi) (0.14.0)
# Collecting transformers>=4.42.0 (from byaldi)
#   Downloading transformers-4.47.1-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->mteb==1.6.35->byaldi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->mteb==1.6.35->byaldi) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->mteb==1.6.35->byaldi) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->mteb==1.6.35->byaldi) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->mteb==1.6.35->byaldi) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->mteb==1.6.35->byaldi) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->mteb==1.6.35->byaldi) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->mteb==1.6.35->byaldi) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->mteb==1.6.35->byaldi) (2.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->byaldi) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->byaldi) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->byaldi) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->byaldi)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->byaldi)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->byaldi)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->byaldi)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->byaldi)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->byaldi)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->byaldi)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->byaldi)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->byaldi)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->byaldi) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->byaldi) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->byaldi) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->byaldi)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->byaldi) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->byaldi) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->byaldi) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.42.0->byaldi) (0.29.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.42.0->byaldi) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.42.0->byaldi) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.42.0->byaldi) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.42.0->byaldi) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.42.0->byaldi) (0.5.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<0.16,>=0.9->together) (1.5.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from srsly->byaldi) (2.0.10)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.2.0->mteb==1.6.35->byaldi)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi) (2.2.2)
# Collecting xxhash (from datasets>=2.2.0->mteb==1.6.35->byaldi)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.2.0->mteb==1.6.35->byaldi)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec (from torch->byaldi)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->mteb==1.6.35->byaldi) (0.1.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft<0.15.0,>=0.14.0->colpali-engine<0.4.0,>=0.3.4->byaldi) (5.9.5)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from peft<0.15.0,>=0.14.0->colpali-engine<0.4.0,>=0.3.4->byaldi) (1.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.2->mteb==1.6.35->byaldi) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.2->mteb==1.6.35->byaldi) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->byaldi) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.2.0->mteb==1.6.35->byaldi) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.2.0->mteb==1.6.35->byaldi) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.2.0->mteb==1.6.35->byaldi) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.2.0->mteb==1.6.35->byaldi) (1.17.0)
# Downloading Byaldi-0.0.7-py3-none-any.whl (21 kB)
# Downloading mteb-1.6.35-py3-none-any.whl (517 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.9/517.9 kB 32.8 MB/s eta 0:00:00
# Downloading together-1.5.4-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.8/87.8 kB 9.6 MB/s eta 0:00:00
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading colpali_engine-0.3.8-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 4.7 MB/s eta 0:00:00
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 112.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 97.2 MB/s eta 0:00:00
# Downloading transformers-4.47.1-py3-none-any.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 110.3 MB/s eta 0:00:00
# Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (422 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 37.5 MB/s eta 0:00:00
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 41.4 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 18.5 MB/s eta 0:00:00
# Downloading pytrec_eval_terrier-0.5.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.9/287.9 kB 26.8 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 15.3 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 19.5 MB/s eta 0:00:00
# Building wheels for collected packages: gputil
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7392 sha256=9222eea922157360aeff6e1c4e657ada3cc7b638a77a312612448bb35680e3bf
#   Stored in directory: /root/.cache/pip/wheels/2b/4d/8f/55fb4f7b9b591891e8d3f72977c4ec6c7763b39c19f0861595
# Successfully built gputil
# Installing collected packages: gputil, xxhash, pytrec-eval-terrier, pdf2image, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, ninja, jsonlines, fsspec, eval-type-backport, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, transformers, together, datasets, mteb, colpali-engine, byaldi
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.50.2
#     Uninstalling transformers-4.50.2:
#       Successfully uninstalled transformers-4.50.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed byaldi-0.0.7 colpali-engine-0.3.8 datasets-3.5.0 dill-0.3.8 eval-type-backport-0.2.2 fsspec-2024.12.0 gputil-1.4.0 jsonlines-4.0.0 mteb-1.6.35 multiprocess-0.70.16 ninja-1.11.1.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pdf2image-1.17.0 pytrec-eval-terrier-0.5.6 together-1.5.4 transformers-4.47.1 xxhash-3.5.0

# %%
# !sudo apt-get install -y poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.6).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.

# %%
# Paste in your Together AI API Key or load it
api_key = os.environ.get("TOGETHER_API_KEY")

# %% [markdown]
# ### Initialize the ColPali Model

# %%
import os
from pathlib import Path
from byaldi import RAGMultiModalModel

# Initialize RAGMultiModalModel
model = RAGMultiModalModel.from_pretrained("vidore/colqwen2-v0.1")
# Out:
# Verbosity is set to 1 (active). Pass verbose=0 to make quieter.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# adapter_config.json:   0%|          | 0.00/728 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/56.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.85G [00:00<?, ?B/s]
# `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/220 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/74.0M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/4.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/392 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]

# %% [markdown]
# ### The document we will be retrieving from is a 39 page Nvidia investor presentation from 2023: [Investor Presentation October 2023](https://s201.q4cdn.com/141608511/files/doc_presentations/2023/Oct/01/ndr_presentation_oct_2023_final.pdf)

# %%
# 1. Download with SSL verification disabled
# !wget --no-check-certificate https://ongcindia.com/documents/77751/2660534/ar2023-24.pdf

# 2. Rename the ACTUAL downloaded file
# !mv ar2023-24.pdf ongc_annual_report.pdf

# 3. Verify
# !ls -lh ongc_annual_report.pdf
# Out:
# --2025-04-01 05:46:18--  https://ongcindia.com/documents/77751/2660534/ar2023-24.pdf
# Resolving ongcindia.com (ongcindia.com)... 210.212.78.205
# Connecting to ongcindia.com (ongcindia.com)|210.212.78.205|:443... connected.
# WARNING: cannot verify ongcindia.com's certificate, issued by ‘CN=DigiCert Global G2 TLS RSA SHA256 2020 CA1,O=DigiCert Inc,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200
# Length: 20060120 (19M) [application/pdf]
# Saving to: ‘ar2023-24.pdf’
#
# ar2023-24.pdf       100%[===================>]  19.13M  1.89MB/s    in 11s
#
# 2025-04-01 05:46:30 (1.81 MB/s) - ‘ar2023-24.pdf’ saved [20060120/20060120]
#
# -rw-r--r-- 1 root root 20M Aug  7  2024 ongc_annual_report.pdf

# %% [markdown]
# ### Lets create our index that will store the embeddings for the page images.
#
# Caution: This cell below takes ~5 mins to index the whole PDF!

# %%
# Use ColQwen2 to index and store the presentation
index_name = "nvidia_index"
model.index(input_path=Path("/content/ongc_annual_report.pdf"),
    index_name=index_name,
    store_collection_with_index=True, # Stores base64 images along with the vectors
    overwrite=True
)
# Out:
# Added page 1 of document 0 to index.
# Added page 2 of document 0 to index.
# Added page 3 of document 0 to index.
# Added page 4 of document 0 to index.
# Added page 5 of document 0 to index.
# Added page 6 of document 0 to index.
# Added page 7 of document 0 to index.
# Added page 8 of document 0 to index.
# Added page 9 of document 0 to index.
# Added page 10 of document 0 to index.
# Added page 11 of document 0 to index.
# Added page 12 of document 0 to index.
# Added page 13 of document 0 to index.
# Added page 14 of document 0 to index.
# Added page 15 of document 0 to index.
# Added page 16 of document 0 to index.
# Added page 17 of document 0 to index.
# Added page 18 of document 0 to index.
# Added page 19 of document 0 to index.
# Added page 20 of document 0 to index.
# Added page 21 of document 0 to index.
# Added page 22 of document 0 to index.
# Added page 23 of document 0 to index.
# Added page 24 of document 0 to index.
# Added page 25 of document 0 to index.
# Added page 26 of document 0 to index.
# Added page 27 of document 0 to index.
# Added page 28 of document 0 to index.
# Added page 29 of document 0 to index.
# Added page 30 of document 0 to index.
# Added page 31 of document 0 to index.
# Added page 32 of document 0 to index.
# Added page 33 of document 0 to index.
# Added page 34 of document 0 to index.
# Added page 35 of document 0 to index.
# Added page 36 of document 0 to index.
# Added page 37 of document 0 to index.
# Added page 38 of document 0 to index.
# Added page 39 of document 0 to index.
# Added page 40 of document 0 to index.
# Added page 41 of document 0 to index.
# Added page 42 of document 0 to index.
# Added page 43 of document 0 to index.
# Added page 44 of document 0 to index.
# Added page 45 of document 0 to index.
# Added page 46 of document 0 to index.
# Added page 47 of document 0 to index.
# Added page 48 of document 0 to index.
# Added page 49 of document 0 to index.
# Added page 50 of document 0 to index.
# Added page 51 of document 0 to index.
# Added page 52 of document 0 to index.
# Added page 53 of document 0 to index.
# Added page 54 of document 0 to index.
# Added page 55 of document 0 to index.
# Added page 56 of document 0 to index.
# Added page 57 of document 0 to index.
# Added page 58 of document 0 to index.
# Added page 59 of document 0 to index.
# Added page 60 of document 0 to index.
# Added page 61 of document 0 to index.
# Added page 62 of document 0 to index.
# Added page 63 of document 0 to index.
# Added page 64 of document 0 to index.
# Added page 65 of document 0 to index.
# Added page 66 of document 0 to index.
# Added page 67 of document 0 to index.
# Added page 68 of document 0 to index.
# Added page 69 of document 0 to index.
# Added page 70 of document 0 to index.
# Added page 71 of document 0 to index.
# Added page 72 of document 0 to index.
# Added page 73 of document 0 to index.
# Added page 74 of document 0 to index.
# Added page 75 of document 0 to index.
# Added page 76 of document 0 to index.
# Added page 77 of document 0 to index.
# Added page 78 of document 0 to index.
# Added page 79 of document 0 to index.
# Added page 80 of document 0 to index.
# Added page 81 of document 0 to index.
# Added page 82 of document 0 to index.
# Added page 83 of document 0 to index.
# Added page 84 of document 0 to index.
# Added page 85 of document 0 to index.
# Added page 86 of document 0 to index.
# Added page 87 of document 0 to index.
# Added page 88 of document 0 to index.
# Added page 89 of document 0 to index.
# Added page 90 of document 0 to index.
# Added page 91 of document 0 to index.
# Added page 92 of document 0 to index.
# Added page 93 of document 0 to index.
# Added page 94 of document 0 to index.
# Added page 95 of document 0 to index.
# Added page 96 of document 0 to index.
# Added page 97 of document 0 to index.
# Added page 98 of document 0 to index.
# Added page 99 of document 0 to index.
# Added page 100 of document 0 to index.
# Added page 101 of document 0 to index.
# Added page 102 of document 0 to index.
# Added page 103 of document 0 to index.
# Added page 104 of document 0 to index.
# Added page 105 of document 0 to index.
# Added page 106 of document 0 to index.
# Added page 107 of document 0 to index.
# Added page 108 of document 0 to index.
# Added page 109 of document 0 to index.
# Added page 110 of document 0 to index.
# Added page 111 of document 0 to index.
# Added page 112 of document 0 to index.
# Added page 113 of document 0 to index.
# Added page 114 of document 0 to index.
# Added page 115 of document 0 to index.
# Added page 116 of document 0 to index.
# Added page 117 of document 0 to index.
# Added page 118 of document 0 to index.
# Added page 119 of document 0 to index.
# Added page 120 of document 0 to index.
# Added page 121 of document 0 to index.
# Added page 122 of document 0 to index.
# Added page 123 of document 0 to index.
# Added page 124 of document 0 to index.
# Added page 125 of document 0 to index.
# Added page 126 of document 0 to index.
# Added page 127 of document 0 to index.
# Added page 128 of document 0 to index.
# Added page 129 of document 0 to index.
# Added page 130 of document 0 to index.
# Added page 131 of document 0 to index.
# Added page 132 of document 0 to index.
# Added page 133 of document 0 to index.
# Added page 134 of document 0 to index.
# Added page 135 of document 0 to index.
# Added page 136 of document 0 to index.
# Added page 137 of document 0 to index.
# Added page 138 of document 0 to index.
# Added page 139 of document 0 to index.
# Added page 140 of document 0 to index.
# Added page 141 of document 0 to index.
# Added page 142 of document 0 to index.
# Added page 143 of document 0 to index.
# Added page 144 of document 0 to index.
# Added page 145 of document 0 to index.
# Added page 146 of document 0 to index.
# Added page 147 of document 0 to index.
# Added page 148 of document 0 to index.
# Added page 149 of document 0 to index.
# Added page 150 of document 0 to index.
# Added page 151 of document 0 to index.
# Added page 152 of document 0 to index.
# Added page 153 of document 0 to index.
# Added page 154 of document 0 to index.
# Added page 155 of document 0 to index.
# Added page 156 of document 0 to index.
# Added page 157 of document 0 to index.
# Added page 158 of document 0 to index.
# Added page 159 of document 0 to index.
# Added page 160 of document 0 to index.
# Added page 161 of document 0 to index.
# Added page 162 of document 0 to index.
# Added page 163 of document 0 to index.
# Added page 164 of document 0 to index.
# Added page 165 of document 0 to index.
# Added page 166 of document 0 to index.
# Added page 167 of document 0 to index.
# Added page 168 of document 0 to index.
# Added page 169 of document 0 to index.
# Added page 170 of document 0 to index.
# Added page 171 of document 0 to index.
# Added page 172 of document 0 to index.
# Added page 173 of document 0 to index.
# Added page 174 of document 0 to index.
# Added page 175 of document 0 to index.
# Added page 176 of document 0 to index.
# Added page 177 of document 0 to index.
# Added page 178 of document 0 to index.
# Added page 179 of document 0 to index.
# Added page 180 of document 0 to index.
# Added page 181 of document 0 to index.
# Added page 182 of document 0 to index.
# Added page 183 of document 0 to index.
# Added page 184 of document 0 to index.
# Added page 185 of document 0 to index.
# Added page 186 of document 0 to index.
# Added page 187 of document 0 to index.
# Added page 188 of document 0 to index.
# Added page 189 of document 0 to index.
# Added page 190 of document 0 to index.
# Added page 191 of document 0 to index.
# Added page 192 of document 0 to index.
# Added page 193 of document 0 to index.
# Added page 194 of document 0 to index.
# Added page 195 of document 0 to index.
# Added page 196 of document 0 to index.
# Added page 197 of document 0 to index.
# Added page 198 of document 0 to index.
# Added page 199 of document 0 to index.
# Added page 200 of document 0 to index.
# Added page 201 of document 0 to index.
# Added page 202 of document 0 to index.
# Added page 203 of document 0 to index.
# Added page 204 of document 0 to index.
# Added page 205 of document 0 to index.
# Added page 206 of document 0 to index.
# Added page 207 of document 0 to index.
# Added page 208 of document 0 to index.
# Added page 209 of document 0 to index.
# Added page 210 of document 0 to index.
# Added page 211 of document 0 to index.
# Added page 212 of document 0 to index.
# Added page 213 of document 0 to index.
# Added page 214 of document 0 to index.
# Added page 215 of document 0 to index.
# Added page 216 of document 0 to index.
# Added page 217 of document 0 to index.
# Added page 218 of document 0 to index.
# Added page 219 of document 0 to index.
# Added page 220 of document 0 to index.
# Added page 221 of document 0 to index.
# Added page 222 of document 0 to index.
# Added page 223 of document 0 to index.
# Added page 224 of document 0 to index.
# Added page 225 of document 0 to index.
# Added page 226 of document 0 to index.
# Added page 227 of document 0 to index.
# Added page 228 of document 0 to index.
# Added page 229 of document 0 to index.
# Added page 230 of document 0 to index.
# Added page 231 of document 0 to index.
# Added page 232 of document 0 to index.
# Added page 233 of document 0 to index.
# Added page 234 of document 0 to index.
# Added page 235 of document 0 to index.
# Added page 236 of document 0 to index.
# Added page 237 of document 0 to index.
# Added page 238 of document 0 to index.
# Added page 239 of document 0 to index.
# Added page 240 of document 0 to index.
# Added page 241 of document 0 to index.
# Added page 242 of document 0 to index.
# Added page 243 of document 0 to index.
# Added page 244 of document 0 to index.
# Added page 245 of document 0 to index.
# Added page 246 of document 0 to index.
# Added page 247 of document 0 to index.
# Added page 248 of document 0 to index.
# Added page 249 of document 0 to index.
# Added page 250 of document 0 to index.
# Added page 251 of document 0 to index.
# Added page 252 of document 0 to index.
# Added page 253 of document 0 to index.
# Added page 254 of document 0 to index.
# Added page 255 of document 0 to index.
# Added page 256 of document 0 to index.
# Added page 257 of document 0 to index.
# Added page 258 of document 0 to index.
# Added page 259 of document 0 to index.
# Added page 260 of document 0 to index.
# Added page 261 of document 0 to index.
# Added page 262 of document 0 to index.
# Added page 263 of document 0 to index.
# Added page 264 of document 0 to index.
# Added page 265 of document 0 to index.
# Added page 266 of document 0 to index.
# Added page 267 of document 0 to index.
# Added page 268 of document 0 to index.
# Added page 269 of document 0 to index.
# Added page 270 of document 0 to index.
# Added page 271 of document 0 to index.
# Added page 272 of document 0 to index.
# Added page 273 of document 0 to index.
# Added page 274 of document 0 to index.
# Added page 275 of document 0 to index.
# Added page 276 of document 0 to index.
# Added page 277 of document 0 to index.
# Added page 278 of document 0 to index.
# Added page 279 of document 0 to index.
# Added page 280 of document 0 to index.
# Added page 281 of document 0 to index.
# Added page 282 of document 0 to index.
# Added page 283 of document 0 to index.
# Added page 284 of document 0 to index.
# Added page 285 of document 0 to index.
# Added page 286 of document 0 to index.
# Added page 287 of document 0 to index.
# Added page 288 of document 0 to index.
# Added page 289 of document 0 to index.
# Added page 290 of document 0 to index.
# Added page 291 of document 0 to index.
# Added page 292 of document 0 to index.
# Added page 293 of document 0 to index.
# Added page 294 of document 0 to index.
# Added page 295 of document 0 to index.
# Added page 296 of document 0 to index.
# Added page 297 of document 0 to index.
# Added page 298 of document 0 to index.
# Added page 299 of document 0 to index.
# Added page 300 of document 0 to index.
# Added page 301 of document 0 to index.
# Added page 302 of document 0 to index.
# Added page 303 of document 0 to index.
# Added page 304 of document 0 to index.
# Added page 305 of document 0 to index.
# Added page 306 of document 0 to index.
# Added page 307 of document 0 to index.
# Added page 308 of document 0 to index.
# Added page 309 of document 0 to index.
# Added page 310 of document 0 to index.
# Added page 311 of document 0 to index.
# Added page 312 of document 0 to index.
# Added page 313 of document 0 to index.
# Added page 314 of document 0 to index.
# Added page 315 of document 0 to index.
# Added page 316 of document 0 to index.
# Added page 317 of document 0 to index.
# Added page 318 of document 0 to index.
# Added page 319 of document 0 to index.
# Added page 320 of document 0 to index.
# Added page 321 of document 0 to index.
# Added page 322 of document 0 to index.
# Added page 323 of document 0 to index.
# Added page 324 of document 0 to index.
# Added page 325 of document 0 to index.
# Added page 326 of document 0 to index.
# Added page 327 of document 0 to index.
# Added page 328 of document 0 to index.
# Added page 329 of document 0 to index.
# Added page 330 of document 0 to index.
# Added page 331 of document 0 to index.
# Added page 332 of document 0 to index.
# Added page 333 of document 0 to index.
# Added page 334 of document 0 to index.
# Added page 335 of document 0 to index.
# Added page 336 of document 0 to index.
# Added page 337 of document 0 to index.
# Added page 338 of document 0 to index.
# Added page 339 of document 0 to index.
# Added page 340 of document 0 to index.
# Added page 341 of document 0 to index.
# Added page 342 of document 0 to index.
# Added page 343 of document 0 to index.
# Added page 344 of document 0 to index.
# Added page 345 of document 0 to index.
# Added page 346 of document 0 to index.
# Added page 347 of document 0 to index.
# Added page 348 of document 0 to index.
# Added page 349 of document 0 to index.
# Added page 350 of document 0 to index.
# Added page 351 of document 0 to index.
# Added page 352 of document 0 to index.
# Added page 353 of document 0 to index.
# Added page 354 of document 0 to index.
# Added page 355 of document 0 to index.
# Added page 356 of document 0 to index.
# Added page 357 of document 0 to index.
# Added page 358 of document 0 to index.
# Added page 359 of document 0 to index.
# Added page 360 of document 0 to index.
# Added page 361 of document 0 to index.
# Added page 362 of document 0 to index.
# Added page 363 of document 0 to index.
# Added page 364 of document 0 to index.
# Added page 365 of document 0 to index.
# Added page 366 of document 0 to index.
# Added page 367 of document 0 to index.
# Added page 368 of document 0 to index.
# Added page 369 of document 0 to index.
# Added page 370 of document 0 to index.
# Added page 371 of document 0 to index.
# Added page 372 of document 0 to index.
# Added page 373 of document 0 to index.
# Added page 374 of document 0 to index.
# Added page 375 of document 0 to index.
# Added page 376 of document 0 to index.
# Added page 377 of document 0 to index.
# Added page 378 of document 0 to index.
# Added page 379 of document 0 to index.
# Added page 380 of document 0 to index.
# Added page 381 of document 0 to index.
# Added page 382 of document 0 to index.
# Added page 383 of document 0 to index.
# Added page 384 of document 0 to index.
# Added page 385 of document 0 to index.
# Added page 386 of document 0 to index.
# Added page 387 of document 0 to index.
# Added page 388 of document 0 to index.
# Added page 389 of document 0 to index.
# Added page 390 of document 0 to index.
# Added page 391 of document 0 to index.
# Added page 392 of document 0 to index.
# Added page 393 of document 0 to index.
# Added page 394 of document 0 to index.
# Added page 395 of document 0 to index.
# Added page 396 of document 0 to index.
# Added page 397 of document 0 to index.
# Added page 398 of document 0 to index.
# Added page 399 of document 0 to index.
# Added page 400 of document 0 to index.
# Added page 401 of document 0 to index.
# Added page 402 of document 0 to index.
# Added page 403 of document 0 to index.
# Added page 404 of document 0 to index.
# Added page 405 of document 0 to index.
# Added page 406 of document 0 to index.
# Added page 407 of document 0 to index.
# Added page 408 of document 0 to index.
# Added page 409 of document 0 to index.
# Added page 410 of document 0 to index.
# Added page 411 of document 0 to index.
# Added page 412 of document 0 to index.
# Added page 413 of document 0 to index.
# Added page 414 of document 0 to index.
# Added page 415 of document 0 to index.
# Added page 416 of document 0 to index.
# Added page 417 of document 0 to index.
# Added page 418 of document 0 to index.
# Added page 419 of document 0 to index.
# Added page 420 of document 0 to index.
# Added page 421 of document 0 to index.
# Added page 422 of document 0 to index.
# Added page 423 of document 0 to index.
# Added page 424 of document 0 to index.
# Added page 425 of document 0 to index.
# Added page 426 of document 0 to index.
# Added page 427 of document 0 to index.
# Added page 428 of document 0 to index.
# Added page 429 of document 0 to index.
# Added page 430 of document 0 to index.
# Added page 431 of document 0 to index.
# Added page 432 of document 0 to index.
# Added page 433 of document 0 to index.
# Added page 434 of document 0 to index.
# Added page 435 of document 0 to index.
# Added page 436 of document 0 to index.
# Added page 437 of document 0 to index.
# Added page 438 of document 0 to index.
# Added page 439 of document 0 to index.
# Added page 440 of document 0 to index.
# Added page 441 of document 0 to index.
# Added page 442 of document 0 to index.
# Added page 443 of document 0 to index.
# Added page 444 of document 0 to index.
# Added page 445 of document 0 to index.
# Added page 446 of document 0 to index.
# Added page 447 of document 0 to index.
# Added page 448 of document 0 to index.
# Added page 449 of document 0 to index.
# Added page 450 of document 0 to index.
# Added page 451 of document 0 to index.
# Added page 452 of document 0 to index.
# Added page 453 of document 0 to index.
# Added page 454 of document 0 to index.
# Added page 455 of document 0 to index.
# Added page 456 of document 0 to index.
# Added page 457 of document 0 to index.
# Added page 458 of document 0 to index.
# Added page 459 of document 0 to index.
# Added page 460 of document 0 to index.
# Added page 461 of document 0 to index.
# Added page 462 of document 0 to index.
# Added page 463 of document 0 to index.
# Added page 464 of document 0 to index.
# Added page 465 of document 0 to index.
# Added page 466 of document 0 to index.
# Added page 467 of document 0 to index.
# Added page 468 of document 0 to index.
# Added page 469 of document 0 to index.
# Added page 470 of document 0 to index.
# Added page 471 of document 0 to index.
# Added page 472 of document 0 to index.
# Added page 473 of document 0 to index.
# Added page 474 of document 0 to index.
# Added page 475 of document 0 to index.
# Added page 476 of document 0 to index.
# Added page 477 of document 0 to index.
# Added page 478 of document 0 to index.
# Added page 479 of document 0 to index.
# Added page 480 of document 0 to index.
# Added page 481 of document 0 to index.
# Added page 482 of document 0 to index.
# Added page 483 of document 0 to index.
# Added page 484 of document 0 to index.
# Added page 485 of document 0 to index.
# Added page 486 of document 0 to index.
# Added page 487 of document 0 to index.
# Added page 488 of document 0 to index.
# Added page 489 of document 0 to index.
# Added page 490 of document 0 to index.
# Added page 491 of document 0 to index.
# Added page 492 of document 0 to index.
# Added page 493 of document 0 to index.
# Added page 494 of document 0 to index.
# Added page 495 of document 0 to index.
# Added page 496 of document 0 to index.
# Added page 497 of document 0 to index.
# Added page 498 of document 0 to index.
# Added page 499 of document 0 to index.
# Added page 500 of document 0 to index.
# Added page 501 of document 0 to index.
# Added page 502 of document 0 to index.
# Added page 503 of document 0 to index.
# Added page 504 of document 0 to index.
# Added page 505 of document 0 to index.
# Added page 506 of document 0 to index.
# Added page 507 of document 0 to index.
# Added page 508 of document 0 to index.
# Added page 509 of document 0 to index.
# Added page 510 of document 0 to index.
# Added page 511 of document 0 to index.
# Added page 512 of document 0 to index.
# Added page 513 of document 0 to index.
# Added page 514 of document 0 to index.
# Added page 515 of document 0 to index.
# Added page 516 of document 0 to index.
# Added page 517 of document 0 to index.
# Added page 518 of document 0 to index.
# Added page 519 of document 0 to index.
# Added page 520 of document 0 to index.
# Added page 521 of document 0 to index.
# Added page 522 of document 0 to index.
# Added page 523 of document 0 to index.
# Added page 524 of document 0 to index.
# Added page 525 of document 0 to index.
# Added page 526 of document 0 to index.
# Added page 527 of document 0 to index.
# Added page 528 of document 0 to index.
# Added page 529 of document 0 to index.
# Added page 530 of document 0 to index.
# Added page 531 of document 0 to index.
# Added page 532 of document 0 to index.
# Added page 533 of document 0 to index.
# Added page 534 of document 0 to index.
# Added page 535 of document 0 to index.
# Added page 536 of document 0 to index.
# Added page 537 of document 0 to index.
# Added page 538 of document 0 to index.
# Added page 539 of document 0 to index.
# Added page 540 of document 0 to index.
# Added page 541 of document 0 to index.
# Added page 542 of document 0 to index.
# Added page 543 of document 0 to index.
# Added page 544 of document 0 to index.
# Added page 545 of document 0 to index.
# Added page 546 of document 0 to index.
# Added page 547 of document 0 to index.
# Added page 548 of document 0 to index.
# Added page 549 of document 0 to index.
# Added page 550 of document 0 to index.
# Added page 551 of document 0 to index.
# Added page 552 of document 0 to index.
# Added page 553 of document 0 to index.
# Added page 554 of document 0 to index.
# Added page 555 of document 0 to index.
# Added page 556 of document 0 to index.
# Added page 557 of document 0 to index.
# Added page 558 of document 0 to index.
# Added page 559 of document 0 to index.
# Added page 560 of document 0 to index.
# Added page 561 of document 0 to index.
# Added page 562 of document 0 to index.
# Added page 563 of document 0 to index.
# Added page 564 of document 0 to index.
# Added page 565 of document 0 to index.
# Added page 566 of document 0 to index.
# Added page 567 of document 0 to index.
# Added page 568 of document 0 to index.
# Added page 569 of document 0 to index.
# Added page 570 of document 0 to index.
# Added page 571 of document 0 to index.
# Added page 572 of document 0 to index.
# Added page 573 of document 0 to index.
# Added page 574 of document 0 to index.
# Added page 575 of document 0 to index.
# Added page 576 of document 0 to index.
# Added page 577 of document 0 to index.
# Added page 578 of document 0 to index.
# Added page 579 of document 0 to index.
# Added page 580 of document 0 to index.
# Added page 581 of document 0 to index.
# Added page 582 of document 0 to index.
# Added page 583 of document 0 to index.
# Added page 584 of document 0 to index.
# Added page 585 of document 0 to index.
# Added page 586 of document 0 to index.
# Added page 587 of document 0 to index.
# Added page 588 of document 0 to index.
# Added page 589 of document 0 to index.
# Added page 590 of document 0 to index.
# Added page 591 of document 0 to index.
# Added page 592 of document 0 to index.
# Added page 593 of document 0 to index.
# Added page 594 of document 0 to index.
# Added page 595 of document 0 to index.
# Added page 596 of document 0 to index.
# Added page 597 of document 0 to index.
# Added page 598 of document 0 to index.
# Added page 599 of document 0 to index.
# Added page 600 of document 0 to index.
# Added page 601 of document 0 to index.
# Added page 602 of document 0 to index.
# Added page 603 of document 0 to index.
# Added page 604 of document 0 to index.
# Added page 605 of document 0 to index.
# Added page 606 of document 0 to index.
# Added page 607 of document 0 to index.
# Added page 608 of document 0 to index.
# Added page 609 of document 0 to index.
# Added page 610 of document 0 to index.
# Added page 611 of document 0 to index.
# Added page 612 of document 0 to index.
# Added page 613 of document 0 to index.
# Added page 614 of document 0 to index.
# Added page 615 of document 0 to index.
# Added page 616 of document 0 to index.
# Added page 617 of document 0 to index.
# Added page 618 of document 0 to index.
# Added page 619 of document 0 to index.
# Added page 620 of document 0 to index.
# Added page 621 of document 0 to index.
# Added page 622 of document 0 to index.
# Added page 623 of document 0 to index.
# Added page 624 of document 0 to index.
# Added page 625 of document 0 to index.
# Added page 626 of document 0 to index.
# Added page 627 of document 0 to index.
# Added page 628 of document 0 to index.
# Added page 629 of document 0 to index.
# Added page 630 of document 0 to index.
# Added page 631 of document 0 to index.
# Added page 632 of document 0 to index.
# Added page 633 of document 0 to index.
# Added page 634 of document 0 to index.
# Added page 635 of document 0 to index.
# Added page 636 of document 0 to index.
# Added page 637 of document 0 to index.
# Added page 638 of document 0 to index.
# Added page 639 of document 0 to index.
# Added page 640 of document 0 to index.
# Added page 641 of document 0 to index.
# Added page 642 of document 0 to index.
# Added page 643 of document 0 to index.
# Added page 644 of document 0 to index.
# Added page 645 of document 0 to index.
# Added page 646 of document 0 to index.
# Added page 647 of document 0 to index.
# Added page 648 of document 0 to index.
# Added page 649 of document 0 to index.
# Added page 650 of document 0 to index.
# Added page 651 of document 0 to index.
# Added page 652 of document 0 to index.
# Added page 653 of document 0 to index.
# Added page 654 of document 0 to index.
# Added page 655 of document 0 to index.
# Added page 656 of document 0 to index.
# Added page 657 of document 0 to index.
# Added page 658 of document 0 to index.
# Added page 659 of document 0 to index.
# Added page 660 of document 0 to index.
# Added page 661 of document 0 to index.
# Added page 662 of document 0 to index.
# Added page 663 of document 0 to index.
# Added page 664 of document 0 to index.
# Added page 665 of document 0 to index.
# Added page 666 of document 0 to index.
# Added page 667 of document 0 to index.
# Added page 668 of document 0 to index.
# Added page 669 of document 0 to index.
# Added page 670 of document 0 to index.
# Added page 671 of document 0 to index.
# Added page 672 of document 0 to index.
# Added page 673 of document 0 to index.
# Added page 674 of document 0 to index.
# Added page 675 of document 0 to index.
# Added page 676 of document 0 to index.
# Added page 677 of document 0 to index.
# Added page 678 of document 0 to index.
# Added page 679 of document 0 to index.
# Added page 680 of document 0 to index.
# Added page 681 of document 0 to index.
# Added page 682 of document 0 to index.
# Added page 683 of document 0 to index.
# Added page 684 of document 0 to index.
# Added page 685 of document 0 to index.
# Added page 686 of document 0 to index.
# Added page 687 of document 0 to index.
# Added page 688 of document 0 to index.
# Added page 689 of document 0 to index.
# Added page 690 of document 0 to index.
# Added page 691 of document 0 to index.
# Added page 692 of document 0 to index.
# Added page 693 of document 0 to index.
# Added page 694 of document 0 to index.
# Added page 695 of document 0 to index.
# Added page 696 of document 0 to index.
# Added page 697 of document 0 to index.
# Added page 698 of document 0 to index.
# Added page 699 of document 0 to index.
# Added page 700 of document 0 to index.
# Added page 701 of document 0 to index.
# Added page 702 of document 0 to index.
# Added page 703 of document 0 to index.
# Added page 704 of document 0 to index.
# Added page 705 of document 0 to index.
# Added page 706 of document 0 to index.
# Added page 707 of document 0 to index.
# Added page 708 of document 0 to index.
# Added page 709 of document 0 to index.
# Added page 710 of document 0 to index.
# Added page 711 of document 0 to index.
# Added page 712 of document 0 to index.
# Index exported to .byaldi/nvidia_index
# Index exported to .byaldi/nvidia_index
# {0: '/content/ongc_annual_report.pdf'}

# %% [markdown]
# ### This concludes the indexing of the PDF phase - everything below happens at query time.
#
# <img src="https://github.com/togethercomputer/together-cookbook/blob/main/images/colpali_arch.png?raw=1" width="700">

# %% [markdown]
# ### Let's query our indexed document.
#
# Here the important thing to note is that the query is asking for details that are found on page 25 of the PDF!

# %%
# Lets query our index and retrieve the page that has content with the highest similarity to the query

# The Data Centre revenue results are on page 25 - for context!
query = "How has the company’s R&D investment contributed to innovation and competitive advantage?"
results = model.search(query, k=5)

print(f"Search results for '{query}':")
for result in results:
    print(f"Doc ID: {result.doc_id}, Page: {result.page_num}, Score: {result.score}")

print("Test completed successfully!")
# Out:
# Search results for 'How has the company’s R&D investment contributed to innovation and competitive advantage?':
# Doc ID: 0, Page: 48, Score: 18.625
# Doc ID: 0, Page: 46, Score: 17.875
# Doc ID: 0, Page: 47, Score: 17.375
# Doc ID: 0, Page: 117, Score: 16.75
# Doc ID: 0, Page: 34, Score: 16.75
# Test completed successfully!

# %% [markdown]
# ### Notice that ColQwen2 is able to retrieve that correct page with the highest similarity!

# %% [markdown]
# <img src="https://github.com/togethercomputer/together-cookbook/blob/main/images/page_25.png?raw=1" width="700">

# %% [markdown]
# ### How does this work? What happens under the hood between the different pages and query token?
#
# The interaction operation between page image patch and query text token representations to score each page of the document is what allows this great retreival performance.
#
# Typically each image is resized and cut into patch sizes of 16x16 pixels. These patches are then embedded into 128 dimensional vectors which are stored and used to perform the MaxSim and late interaction operations between the image and text tokens. ColPali is a multi-vector approach because it produces multiple vectors for each image/query; one vector for each token instead of just one vector for all tokens.
#
# <img src="https://github.com/togethercomputer/together-cookbook/blob/main/images/ColPaliMaxSim-1.png?raw=1" width="700">

# %% [markdown]
# The retrieval step takes about 185 ms.

# %%
# %%timeit
model.search(query, k=5)
# Out:
# 241 ms ± 2.25 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## Lets now pass in the retrieved page to the Llama-3.2 90B Vision Model.
#
# This model will read the question: `"What are the half year data centre renevue results and the 5 year CAGR for Nivida data centre revenue?"`
#
# And take in the retrieved page and produce an answer!
#
# You can pass in a URL to the image of the retrieved page or a base64 encoded version of the image.

# %%
# Since we stored the collection along with the index we have the base64 images of all PDF pages aswell!
model.search(query, k=1)
# Out:
# [{'doc_id': 0, 'page_num': 68, 'score': 13.625, 'metadata': {}, 'base64': '...'}]

# %%
returned_page = model.search(query, k=1)[0].base64

# %% [markdown]
# ## We'll use a [Together AI](together.ai) inference endpoint to access the Llama-3.2 90B Vision model

# %%
import os
from together import Together

client = Together(api_key = api_key)

response = client.chat.completions.create(
  model="meta-llama/Llama-3.2-90B-Vision-Instruct-Turbo",
  messages=[
    {
      "role": "user",
      "content": [
        {"type": "text", "text": query}, #query
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{returned_page}", #retrieved page image
          },
        },
      ],
    }
  ],
  max_tokens=300,
)

print(response.choices[0].message.content)
# Out:
# The report highlights the company's commitment to research and development (R&D) with an expenditure of ₹228.11 Crore during FY'24, building on its continuous exploration programme. This investment is crucial in driving innovation and achieving a competitive advantage in the energy market. ONGC's focus on R&D has led to notable discoveries and expansions in its reserves, contributing significantly to its operational performance and financial results. As the energy sector evolves under the influence of international economic factors, ongoing technological advancements are essential for sustainability and growth. By consolidating its efforts in R&D, ONGC positions itself to meet future challenges and opportunistically capitalise on new prospects within the industry.
#
# **Key Outcomes of R&D Efforts:**
#
# *   Discovery of nine new hydrocarbon blocks.
# *   Enhancement of reserve replacement ratio.
# *   Operation of 5 discoveries in OALP blocks and 6 discoveries in nomination blocks.
#
# These outcomes underscore the effectiveness of ONGC's R&D strategy in driving exploration and production growth, thereby reinforcing its competitive edge and operational resilience within the dynamic landscape of the energy sector.

# %% [markdown]
# Here we can see that the combination of ColQwen2 as a image retriever and Llama-3.2 90B Vision is a powerful duo for multimodal RAG applications specially with PDFs.
#
# Not only was ColQwen2 able to retrieve the correct page that had the right answer on it but then Llama-3.2 90B Vision was also able to find exactly where on the page this answer was, ignoring all the irrelvant details!
#
# Voila!🎉🎉
#
# Learn more about Llama 3.2 Vision in the [docs](https://docs.together.ai/docs/vision-overview) here!
